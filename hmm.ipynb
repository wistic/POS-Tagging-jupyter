# %%
import os

train_list = []
def dirWalk(source_path, file_list):
    listing = os.listdir(source_path)
    for entry in listing:
        absolute_path = os.path.join(source_path, entry)
        if os.path.isdir(absolute_path):
            dirWalk(absolute_path, file_list)
        else:
            if absolute_path.split('.')[-1] == 'xml':
                file_list.append(absolute_path)
    return file_list
train_list = dirWalk('resources/Train-corpus', train_list)

# %%
import xml.etree.ElementTree as Et

word_tag_freq = dict()
tag_freq = dict()
tag_pair_freq = dict()

for file_name in train_list:
    tree = Et.parse(file_name)
    root = tree.getroot()

    for sent in root.iter('s'):
        sentence = [('<S>', set(['<S>']))]
        for tok in sent.iter():
            if tok.tag == 'w' or tok.tag == 'c':
                if tok.text is not None:
                    sentence.append((tok.text.strip(), set(tok.attrib["c5"].split('-'))))
        sentence.append(('<E>', set(['<E>'])))

        prev = None
        for word, tag in sentence:
            if word not in word_tag_freq:
                word_tag_freq[word] = dict()
            for t in tag:
                word_tag_freq[word][t] = word_tag_freq[word].get(t, 0) + 1/len(tag)
                tag_freq[t] = tag_freq.get(t, 0) + 1/len(tag)
            
            if prev is not None:
                for prev_tag in prev:
                    for current_tag in tag:
                        tag_pair_freq[(prev_tag, current_tag)] = tag_pair_freq.get((prev_tag, current_tag), 0) + 1/(len(prev) * len(tag))
            prev = tag

# %%
transition_prob = dict()

for pair in tag_pair_freq:
    prev, curr = pair
    transition_prob[pair] = tag_pair_freq[pair]/tag_freq[prev]

# TODO: Add 1 count to every tag pair

# %%
emission_prob = dict()

for word in word_tag_freq:
    emission_prob[word] = dict()
    for tag in word_tag_freq[word]:
        emission_prob[word][tag] = word_tag_freq[word][tag]/tag_freq[tag]

# %%
tag_freq.pop('<S>')
tag_freq.pop('<E>')

tag_prob = dict()

total_tag = sum(tag_freq.values())

for tag in tag_freq:
    tag_prob[tag] = tag_freq[tag]/total_tag

# %% [markdown]
# Cleanup resources

# %%
del train_list
del word_tag_freq
del tag_freq
del tag_pair_freq
del tree
del sentence

# %% [markdown]
# Vitterbi Algo

# %%
test_list = []
test_list = dirWalk('resources/Test-corpus', test_list)

# %%
def vitterbi(words:list):
    words.insert(0, '<S>')
    words.append('<E>')
    prev_tags = list()
    prob = list()
    for i in range(0, len(words)):
        prev_tags.append(dict())
        prob.append(dict())

    prob[0]['<S>'] = 1

    for i in range(1, len(words)):

        if words[i] not in emission_prob:
            for t in tag_prob:
                prob[i][t] = 1
                # TODO: Use tag_prob
        else:
            for t in emission_prob[words[i]]:
                prob[i][t] = emission_prob[words[i]][t]


        for curr_tag in prob[i]:
            mx = 0
            mx_tag = None

            for prev_tag in prob[i-1]:

                if (prev_tag, curr_tag) in transition_prob:
                    value = prob[i-1][prev_tag] * transition_prob[(prev_tag, curr_tag)]
                    # else use 1/count of previous
                    if value > mx:
                        mx = value
                        mx_tag = prev_tag

            if mx_tag is None:
                for prev_tag in prob[i-1]:
                    value = prob[i-1][prev_tag]
                if value > mx:
                    mx = value
                    mx_tag = prev_tag

            # For safety
            if mx_tag is None:
                mx_tag = next(iter(prob[i-1]))
                mx = prob[i-1][mx_tag]
            
            prob[i][curr_tag] = mx * prob[i][curr_tag]
            prev_tags[i][curr_tag] = mx_tag
            
    current_tag = '<E>'
    tags = list()
    for i in range(len(words) - 1, 0, -1):
        tags.append(prev_tags[i][current_tag])
        current_tag = prev_tags[i][current_tag]
    
    tags.pop()
    tags.reverse()

    return tags

# %%
correct = 0
incorrect = 0

# %%
import pandas as pd

confusion_matrix = dict.fromkeys(tag_prob.keys())
for key in confusion_matrix.keys():
    confusion_matrix[key] = dict.fromkeys(tag_prob.keys(), 0)

# %%
import xml.etree.ElementTree as Et

for file_name in test_list:
    tree = Et.parse(file_name)
    root = tree.getroot()


    for sent in root.iter('s'):
        words = list()
        truth_tags = list()
        for tok in sent.iter():
            if tok.tag == 'w' or tok.tag == 'c':
                if tok.text is not None:
                    words.append(tok.text.strip())
                    truth_tags.append(set(tok.attrib["c5"].split('-')))
        predicted_tags = vitterbi(words)

        for i in range(0, len(truth_tags)):
            if predicted_tags[i] in truth_tags[i]:
                correct += 1
                confusion_matrix[predicted_tags[i]][predicted_tags[i]] += 1
            else:
                incorrect += 1
                for tag in truth_tags[i]:
                    confusion_matrix[tag][predicted_tags[i]] += 1/len(truth_tags[i])

dataframe = pd.DataFrame(confusion_matrix)
dataframe = dataframe.style.background_gradient()

# %%
display(correct/(correct+incorrect))
# Out:
# 0.9627703044815643

# %%
dataframe
# Out:
# <style  type="text/css" >
# #T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col0,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row1_col1,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row2_col2,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row3_col3,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row4_col4,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row5_col5,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row6_col6,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row7_col7,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row8_col8,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row9_col9,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row10_col10,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row11_col11,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row12_col12,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row13_col13,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row14_col14,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row15_col15,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row16_col16,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row17_col17,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row18_col18,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row19_col19,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row20_col20,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row21_col21,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row22_col22,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row23_col23,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row24_col24,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row25_col25,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row26_col26,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row27_col27,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row28_col28,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row29_col29,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row30_col30,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row31_col31,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row32_col32,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row33_col33,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row34_col34,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row35_col35,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row36_col36,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row37_col37,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row38_col38,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row39_col39,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row40_col40,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row41_col41,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row42_col42,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row43_col43,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row44_col44,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row45_col45,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row46_col46,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row47_col47,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row48_col48,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row49_col49,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row50_col50,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row51_col51,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row52_col52,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row53_col53,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row54_col54,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row55_col55,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row56_col56,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row57_col57,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row58_col58,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row59_col59,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row60_col60{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col1,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col9,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col13,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col18,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col22,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col24,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col59,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row1_col0,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row1_col2,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row1_col41,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row1_col44,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row1_col49,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row3_col2,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row3_col59,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row6_col0,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row6_col29,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row8_col29,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row9_col57,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row12_col1,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row12_col30,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row13_col23,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row15_col57,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row16_col29,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row17_col33,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row18_col57,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row20_col3,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row21_col18,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row21_col29,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row23_col60,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row27_col57,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row34_col0,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row34_col49,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row34_col59,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row51_col59,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row55_col2,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row55_col4,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row59_col51,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row60_col0,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row60_col2,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row60_col12,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row60_col29{
#             background-color:  #fef6fb;
#             color:  #000000;
#         }#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col2,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col12,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row1_col24,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row1_col50,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row4_col57,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row6_col12,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row9_col0,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row11_col9,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row12_col2,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row12_col29,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row16_col12,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row18_col0,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row18_col2,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row23_col43,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row33_col17,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row34_col12,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row55_col29,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row55_col30,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row55_col51{
#             background-color:  #fef6fa;
#             color:  #000000;
#         }#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col3,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col4,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col5,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col6,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col7,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col8,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col10,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col11,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col14,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col15,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col16,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col17,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col19,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col20,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col21,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col23,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col25,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col26,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col27,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col28,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col29,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col30,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col31,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col32,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col33,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col34,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col35,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col36,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col37,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col38,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col39,#T_116abbde_2fc8_11eb_86c6_6fae33da2357row0_col40,#T_116abbde_2fc8_11eb_86c6_6fae33da2

# %%
def judge(confusion_matrix: dict):
    judge_dictionary = dict.fromkeys(confusion_matrix.keys())

    total = 0
    for key in confusion_matrix.keys():
        total += sum(confusion_matrix[key].values())

    for tag in judge_dictionary.keys():
        weight = sum(confusion_matrix[tag].values())
        true_positive = confusion_matrix[tag][tag]
        false_negative = weight - true_positive
        false_positive = 0
        for key in confusion_matrix.keys():
            false_positive += confusion_matrix[key][tag]
        false_positive -= confusion_matrix[tag][tag]
        true_negative = total - true_positive - false_negative - false_positive

        try:
            accuracy = (true_positive + true_negative) / total
        except ZeroDivisionError:
            accuracy = 0
        try:
            precision = true_positive / (true_positive + false_positive)
        except ZeroDivisionError:
            precision = 0
        try:
            recall = true_positive / (true_positive + false_negative)
        except ZeroDivisionError:
            recall = 0
        try:
            f1_score = (2 * precision * recall) / (precision + recall)
        except ZeroDivisionError:
            f1_score = 0

        tag_dictionary = {
            'TP': true_positive,
            'FN': false_negative,
            'FP': false_positive,
            'TN': true_negative,
            'weight': weight,
            'accuracy': accuracy,
            'precision': precision,
            'recall': recall,
            'f1_score': f1_score
        }
        judge_dictionary[tag] = tag_dictionary

    average_f1_score = 0
    for tag in judge_dictionary.keys():
        average_f1_score += judge_dictionary[tag]['f1_score']
    try:
        average_f1_score = average_f1_score / len(judge_dictionary)
    except ZeroDivisionError:
        average_f1_score = 0

    weighted_f1_score = 0
    for tag in judge_dictionary.keys():
        weighted_f1_score += (judge_dictionary[tag]
                              ['f1_score'] * judge_dictionary[tag]['weight'])
    try:
        weighted_f1_score = weighted_f1_score / total
    except ZeroDivisionError:
        weighted_f1_score = 0

    return average_f1_score, weighted_f1_score

# %%
average_f1_score, weighted_f1_score = judge(confusion_matrix)
print("Average F1 score:", average_f1_score)
print("Weighted F1 score:", weighted_f1_score)
# Out:
# Average F1 score: 0.9104793276555465
# Weighted F1 score: 0.9640557337467647
